# %% [markdown]
# <a href="https://colab.research.google.com/github/tarun1208/AgenticAI/blob/main/BasicATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.8 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
  extracted_text=""

  with open(pdf_path,'rb') as file:
    reader=PyPDF2.PdfReader(file)

    for page in reader.pages:
      page_text = page.extract_text()
      if page_text:
        extracted_text+=page.extract_text()

  return extracted_text

# %%
tarun = extract_text_from_pdf('/content/ML_Resume.pdf')
print(tarun)
# Out:
# Nunna Tarun Sri Venkata Sai
# Bhimavaram, India|tarunsrivenkatasai@gmail.com|+91 9553691664
# linkedin.com/in/TarunSriVenkataSai|github.com/tarun1208
# Professional Summary
# Computer Science student with strong proficiency inMachine Learning. Consistently delivers measurable
# outcomes by improving data asset quality, performance, and reliability, including projects that achieved a12%
# increase in model efficacy and a10%reduction in prediction error.
# Technical Skills
# Languages:Java, Python, JavaScript, R
# Frameworks/Tech:Firebase, TensorFlow, Scikit-learn, Pandas, Matplotlib, XGBoost
# Tools:Jupyter Notebook, Colab Notebook, Git, GitHub, VS Code
# Core Competencies:Data Analysis, Predictive Modeling, Feature Engineering, Project Management, Exploratory
# Data Analysis (EDA), Model Evaluation
# Experience
# Machine Learning WorkshopMar 2024 – Jun 2024
# Exploratory Data Analysis
# ...

# %%
from google import genai
client = genai.Client(api_key="AIzaSyCVRe-Cz6P_-8yE1clEhC3dItnoj1snqVc")

# %%
response = client.models.generate_content(
        model = "gemini-2.5-flash",
        contents = (f'here is my context{tarun}, question: give rating for my response')
)

print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=10>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""This is a **strong resume with excellent content and quantifiable achievements**, but it has a **few critical errors** that need immediate attention.
#
# Here's a breakdown:
#
# ---
#
# **Overall Rating: 3.5/5** (Potentially 4.5-5/5 with immediate fixes to critical errors)
#
# **Key Takeaways:** You have fantastic project work, strong skills, and a great way of quantifying your impact. However, the dates in your "Experience" section are a major red flag and must be corrected.
#
# ---
#
# **Strengths:**
#
# 1.  **Quantifiable Achievements:** You consistently use numbers and percentages (12% efficacy, 10% reduction, 0.85 R2, 0.89 R2, 80% user interest, 75% accurate predictions, 77% NPTEL). This is *excellent* and makes your impact clear.
# ...
